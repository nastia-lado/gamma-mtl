# %%
import numpy as np
import matplotlib.pyplot as plt

from database.db_setup import *
# Out:
# config
# Please enter DataJoint username:  root
# Please enter DataJoint password:  ···············
# Connecting root@localhost:3306
# Epiphyte Setup

# %%
scr_stats = pd.PandasDataframe(ScreeningStats())
# Out:
# *patient_id    *session_nr    *unit_id    *position    *stim_id    stim_indic active_trials  pval_scr     pval_bwscr     pval_perm
# +------------+ +------------+ +---------+ +----------+ +---------+ +--------+ +------------+ +----------+ +------------+ +-----------+
# 46             1              0           post         0           =BLOB=     0              1.0          1.0            -1.0
# 46             1              0           post         1           =BLOB=     0              1.0          1.0            -1.0
# 46             1              0           post         2           =BLOB=     0              1.0          1.0            -1.0
# 46             1              0           post         3           =BLOB=     0              1.0          1.0            -1.0
# 46             1              0           post         4           =BLOB=     0              1.0          1.0            -1.0
# ...

# %%
ScreeningAnnotation()

# %%
ScreeningStats & "patient_id='46'" & "pval_scr<0.001" & "stim_id='20'"
